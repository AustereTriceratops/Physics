# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
uniforms = np.random.random(1000)

sns.distplot(uniforms)

# %%
gumbel = -np.log(-np.log(uniforms))

sns.distplot(gumbel)
