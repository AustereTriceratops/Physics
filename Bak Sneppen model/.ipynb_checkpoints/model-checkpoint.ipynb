# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
class Simulation:
    def __init__(self, population_size):
        self.population_size = population_size
        self.population = np.random.random(self.population_size)
        self.longevity = np.zeros(population_size) 
        
        self.history = [self.population]
        self.longevity_history = [self.longevity]
        self.minima = [self.population.min()]
        self.time = 1
        
    def step(self, num):
        for _ in range(num):
            pop = self.population.copy()
            longevity = self.longevity.copy()

            longevity += np.ones(self.population_size)

            minval = pop.min()
            self.minima.append(minval)

            ind = np.where(pop == minval)[0][0]

            for i in range(3):
                longevity[(ind + i - 1) % self.population_size] = 0
                pop[(ind + i - 1) % self.population_size] = np.random.random()

            self.population = pop
            self.longevity = longevity
            
            self.history.append(pop)
            self.longevity_history.append(longevity)
            
            self.time += 1

# %%
sim = Simulation(300)
sim.step(1000)

# %%
fig, ax = plt.subplots(figsize=(8,12))
ax = sns.heatmap(sim.history)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
fig, ax = plt.subplots(figsize=(8,12))
ax = sns.heatmap(sim.longevity_history, cbar=False)
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
sns.lineplot(range(sim.time), sim.minima)  

# upper bound approaches 0.667 https://arxiv.org/pdf/adap-org/9510002.pdf

# %%
sns.distplot(sim.population, kde=False)  #
